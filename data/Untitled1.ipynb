# %%
import os
import pandas as pd
import glob

# %%
file=os.path.abspath('')

# %%
file
# Out:
# '/home/fibonacci/Desktop/time data/data'

# %%
files=os.path.join(file,'updates*.csv')

# %%
files=glob.glob(files)

# %%
files
# Out:
# ['/home/fibonacci/Desktop/time data/data/updates3.csv',
#  '/home/fibonacci/Desktop/time data/data/updates.csv',
#  '/home/fibonacci/Desktop/time data/data/updates1.csv']

# %%
df=pd.concat(map(pd.read_csv,files),ignore_index=True)

# %%
df
# Out:
#      Unnamed: 0  n1radiolog n2age  n3gender  n4modepaym n5referrin  \
# 0             0       44952    24         1           1          4
# 1             1       49459    48         2           1          4
# 2             2       49459    48         1           1          4
# 3             3       50177    60         1           1          4
# 4             4       44952               1           2          4
# ..          ...         ...   ...       ...         ...        ...
# 274          88       56365    34         2           1          4
# 275          89       56370    42         2           1          4
# 276          90       56952    21         2           1          3
# 277          91      486021     0         2           1          3
# 278          92      500370     7         1           2          3
#
#      n6imagingm            n7examinat n9paymenti n10registr  ...       date  \
# 0             2               CT HEAD    9:13:00    9:24:00  ...        NaN
# ...

# %%
df.to_csv('export.csv')
